# %%
import pandas as pd

# %%
# esto es para data estructurada 
# read_csv('path'
#  ,sep='separaciones del archivo comas,puntos,pipe ect'
#  ,header='enque fila estan los encabezados '
#  ,names=['df_books.columns para saber los names, puedes cambiarlos por los que quieras'])

# %%
df_books = pd.read_csv('/home/roy/Recurses/bestsellers.csv',sep=',',header=0,names=['Namessss', 'Autor', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'])

# %%
# Cuando trabajamos con DataFrames limpiar los datos es importante, 
# y me encanta empezar con .info(), ya que nos da un vistazo rápido pero 
# bastante detallado y asi tener un punto de inicio claro.
df_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Namessss     550 non-null    object
#  1   Autor        550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
# df_books.columns para ver el nombre de cada columna

# %%
# esto es para data no estructurada 
# typ es para ponerlo en forma de raw 
pd.read_json('/home/roy/Recurses/HPCharactersDataRaw.json',typ='Series')
# Out:
# 0       {'Name': 'Mrs. Abbott', 'Link': 'https://www.h...
# 1       {'Name': 'Hannah Abbott', 'Link': 'https://www...
# 2       {'Name': 'Abel Treetops', 'Link': 'https://www...
# 3       {'Name': 'Euan Abercrombie', 'Link': 'https://...
# 4       {'Name': 'Aberforth Dumbledore', 'Link': 'http...
#                               ...
# 1935    {'Name': 'Georgi Zdravko', 'Link': 'https://ww...
# 1936    {'Name': 'Zograf', 'Link': 'https://www.hp-lex...
# 1937    {'Name': 'Zonko', 'Link': 'https://www.hp-lexi...
# 1938    {'Name': 'Valentina Vázquez', 'Link': 'https:/...
# 1939    {'Name': 'Zygmunt Budge', 'Link': 'https://www...
# Length: 1940, dtype: object

# %%
# Cuando queramos leer una tabla que está en una página web, podemos utilizar la sentencia:
	# pd.read_html('link',
 # match='dato que tenga la tabla')

# %%
tabs = pd.read_html('https://es.wikipedia.org/wiki/Anexo:Jugadores_de_la_NBA_que_m%C3%A1s_tiempo_han_estado_en_el_mismo_equipo',match= 'Jugador')
len(tabs)
# Out:
# 2

# %%
tabs[0]
# Out:
#     Temp.           Jugador Pos.                                       Equipo  \
# 0      21     Dirk Nowitzki    A                             Dallas Mavericks
# 1      20       Kobe Bryant    B                           Los Angeles Lakers
# 2      19     John Stockton    B                                    Utah Jazz
# 3      19        Tim Duncan  A/P                            San Antonio Spurs
# 4      19     Udonis Haslem    A                                   Miami Heat
# 5      18     Reggie Miller    B                               Indiana Pacers
# 6      16     John Havlicek  A/B                               Boston Celtics
# 7      16     Manu Ginóbili    B                            San Antonio Spurs
# 8      15     Dolph Schayes  A/P      Syracuse Nationals / Philadelphia 76ers
# 9      15         Hal Greer  B/A      Syracuse Nationals / Philadelphia 76ers
# 10     15     Nick Collison  A/P  Seattle SuperSonics / Oklahoma City Thunder
# ...

# %%
# te da los encabezados de la tabla que quieras encontrar 
df = tabs[0]
list(df)
# Out:
# ['Temp.', 'Jugador', 'Pos.', 'Equipo', 'Carrera', 'Notas', 'Ref.']
