# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# sintaxis
# sns.'Tipo de Grafica'(
# 		 data='Dataset',
# 		 x='Data en el eje x',
# 		 y='Data en el eje y',
# 		 hue='Variable de agrupamiento')
# Tipos de Graficas
# relplot (relacional): scatterplot, lineplot.
# displot (distribuciones): histplot, kdeplot, ecdfplot, rugplot.
# catplot (categorica): stripplot, swamplot, boxplot, violinplot, pointplot, barplot

# %%
sns.barplot(x=['A','B','C'], y=[1,3,2])
plt.show()

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.set_theme.html#seaborn.set_theme
#  https://seaborn.pydata.org/generated/seaborn.color_palette.html#seaborn.color_palette

# %%
# de esta manera puedes escoger el estilo del fondo, color etc
sns.set(style='whitegrid', palette='husl', font='', font_scale=1)
sns.barplot(x=['A','B','C'], y=[1,3,2])
plt.show()
