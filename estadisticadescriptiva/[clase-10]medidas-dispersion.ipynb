# %% [markdown]
# # Medidas de dispersión
#
# continuamos con el dataset https://www.kaggle.com/lepchenkov/usedcarscatalog

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('cars.csv')

# %% [markdown]
# # Media, varianza y desviación estándar
#
# MEDIA:Promedio, el valor central de los datos
#
# Parámetro = Poblacional
#
# Estadístico = Muestral
# ![Captura de pantalla 2023-07-05 124946.png](<attachment:Captura de pantalla 2023-07-05 124946.png>)

# %% [markdown]
# VARIANZA:
#
# Distancia de los valores respecto a la media o promedio, es decir, que tan lejos y que tan cerca están cada uno de ellos respecto a la media.
#
# La suma entre las distancias de cada uno de mis valores restando la media poblacional, esto elevado al cuadrado. Sumado cada una de esas diferencia y lo divido al numero de muestras.
#
# Parámetro = Poblacional
#
# Estadístico = Muestral
#
#
# ![Texto alternativo](/home/roy/estadisticadescriptiva/images/imagen2.png)

# %% [markdown]
# En la siguiente formula no hay subestimación ni sobreestimación de la varianza
#
# ![texto](/home/roy/estadisticadescriptiva/images/imagen3.png)

# %% [markdown]
# DESVIACIÓN ESTÁNDAR:
#
# Qué tan alejado el valor respecto al promedio, nos explicará las desviaciones que tendremos en cada uno de los elementos.
#
# Si la desviación estándar es mayor → el conjunto de está muy alejado de la media
#
# Si la desviación estándar es menor→ el conjunto de está muy cerca del promedio
#
# Si la desviación estándar es 0 → los valores son iguales
#
# Parámetro = Poblacional
#
# Estadístico = Muestral
#
# ![texto](/home/roy/estadisticadescriptiva/images/imagen4.png)

# %% [markdown]
# ## VARIANZA VS DESVIACION ESTANDAR
#
#  la varianza y la desviación estándar miden la dispersión o variabilidad de los datos, pero la varianza es el promedio de las diferencias al cuadrado entre cada dato y la media, mientras que la desviación estándar es simplemente la raíz cuadrada de la varianza, lo que la hace más fácil de interpretar y entender en términos de las unidades originales de los datos.

# %%
# Desviación estandar
# mide que tanto estan alejados los datos de la media y
# un numero mas cercano a 0 indica que estan menos alejados 
df['price_usd'].std()
# Out:
# 6428.152018202915

# %%
# Rango = valor max - valor min
# es la distancia de nuestros valores 
rango = df['price_usd'].max() - df['price_usd'].min()
rango
# Out:
# 49999.0

# %%
# Quartiles
median = df['price_usd'].median()
Q1 = df['price_usd'].quantile(q=0.25)
Q3 = df['price_usd'].quantile(q=0.75)
min_val = df['price_usd'].quantile(q=0)
max_val = df['price_usd'].quantile(q=1.0)
print('min {} Q1 {} Q2 o median {} Q3 {} max {}'.format(min_val, Q1, median, Q3, max_val))
# Out:
# min 1.0 Q1 2100.0 Q2 o median 4800.0 Q3 8990.0 max 50000.0

# %% [markdown]
# El IQR (rango intercuartil) es una medida de dispersión estadística que se utiliza para describir la distribución de un conjunto de datos. **El IQR se define como la distancia entre el tercer cuartil (Q3) y el primer cuartil (Q1) de los datos. En otras palabras, el IQR es el rango de valores que se encuentra en el 50% intermedio de los datos.**

# %%
iqr = Q3 - Q1
iqr
# Out:
# 6890.0

# %% [markdown]
# ### Límites para detección de outliers (datos simetricamente distribuidos)
#
# Datos entre $$Q_1 -1.5 \times \text{IQR}$$ y $$Q_3 + 1.5 \times \text{IQR}$$

# %% [markdown]
# Los outliers, también conocidos como valores atípicos, son observaciones que se encuentran significativamente alejadas del resto de los datos en un conjunto de datos. Los outliers son valores que están muy por encima o por debajo del rango típico de los datos y pueden influir en el análisis estadístico de los mismos.

# %%
minlimit = Q1 - 1.5*iqr
maxlimit = Q3 + 1.5*iqr
print('rango para detección de outliers: {}, {}'.format(minlimit, maxlimit))
# Out:
# rango para detección de outliers: -8235.0, 19325.0

# %%
# Configurar el tamaño predeterminado de las figuras de Seaborn
sns.set(rc={'figure.figsize':(11.7,8.27)})

# Crear una figura con dos subplots (subfiguras), uno para un histograma y otro para un boxplot
# `f` es la figura principal y `(ax_hist, ax_box)` son los dos subplots
# `2` indica que habrá dos filas de subplots
# `sharex=True` indica que ambos subplots compartirán el mismo eje x
# `gridspec_kw={"height_ratios": (.6, .4)}` es un argumento que permite especificar la altura relativa de las dos subfiguras, en este caso `.6` para el histograma y `.4` para el boxplot
f, (ax_hist, ax_box) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.6, .4)})

# Crear un histograma utilizando Seaborn y lo asigna al subplot `ax_hist`
# `df['price_usd']` es la serie de datos que se va a graficar en el histograma
sns.histplot(df['price_usd'], ax=ax_hist)

# Crear un boxplot utilizando Seaborn y lo asigna al subplot `ax_box`
# `df['price_usd']` es la serie de datos que se va a graficar en el boxplot
sns.boxplot(df['price_usd'], ax=ax_box)

# Establecer una etiqueta vacía para el eje x del subplot del histograma `ax_hist`
# Esto se hace para que no haya una etiqueta repetida en el eje x, ya que ambos subplots comparten el mismo eje x.
ax_hist.set(xlabel='')
# Out:
# [Text(0.5, 0, '')]

# %% [markdown]
# Es posible calcular varios box-plot separando por una cierta variable categórica:

# %%
sns.boxplot(x = 'engine_fuel', y = 'price_usd', data = df)
# Out:
# <AxesSubplot: xlabel='engine_fuel', ylabel='price_usd'>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=3f569948-e9a8-454f-8f4d-a27aa1610a87' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
